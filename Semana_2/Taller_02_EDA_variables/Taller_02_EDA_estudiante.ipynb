# %% [markdown]
# # Taller — Análisis exploratorio de variables categóricas y numéricas
#
# ### Dataset: `credits.csv`
#
# **Instrucciones generales:**
# - Trabaja en un notebook de Jupyter (Colab o local).
# - Copia el archivo `credits.csv` en la misma carpeta que tu notebook.
# - Donde veas `# TU CÓDIGO AQUÍ`, reemplázalo por tu solución.
# - Responde las preguntas de reflexión en una celda de texto (Markdown), no como comentario de código.
# - Duración estimada: 45-60 minutos.
#
# **Sobre el dataset:** `credits.csv` contiene los créditos (reparto y dirección) de miles de películas/series. Cada fila es una persona acreditada en un título:
# - `person_id`: identificador de la persona.
# - `id`: identificador del título (película/serie).
# - `name`: nombre de la persona.
# - `character`: personaje interpretado (solo aplica a actores).
# - `role`: `ACTOR` o `DIRECTOR`.

# %% [markdown]
# ---
# ## Paso 0 — Preparación

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("credits.csv")
df.head()

# %% [markdown]
# ---
# ## Parte 1 — Variables categóricas
#
# ### Ejercicio 1.1 — Frecuencias absolutas y relativas
# Para la columna `role`, obtén:
# - El conteo de valores por categoría.
# - El porcentaje que representa cada categoría sobre el total.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 1.2 — Categoría de alta cardinalidad
# La columna `name` tiene miles de valores distintos (una persona por fila). En vez de ver todas las categorías, obtén **las 10 personas que más créditos tienen** en el dataset (`value_counts()` y luego quédate con las primeras 10).

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Pregunta de reflexión 1:** ¿La columna `role` está balanceada? ¿A qué se debe (piensa en cuántos directores vs. cuántos actores tiene normalmente una película)? Y en el caso de `name`: si alguien aparece una sola vez en todo el dataset, ¿qué tan confiable sería sacar conclusiones sobre esa persona en particular?

# %% [markdown]
# ### Ejercicio 1.3 — Visualización comparativa
# Crea una figura con **dos gráficos de barras lado a lado**: uno para `role` y otro para las 10 personas con más créditos (ejercicio 1.2), usando `plt.subplots`.

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# TU CÓDIGO AQUÍ

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Parte 2 — Variables numéricas
#
# El dataset no trae directamente una columna numérica "lista para usar" como una nota o un precio — pero sí podemos **construir una**. Vamos a calcular el **tamaño del reparto** (número de actores acreditados) de cada película.
#
# ### Ejercicio 2.1 — Construir la variable numérica y describirla
# 1. Filtra el DataFrame para quedarte solo con las filas donde `role == "ACTOR"`.
# 2. Agrupa por `id` (`groupby`) y cuenta cuántas filas tiene cada grupo (`.size()`). Guarda el resultado en una variable llamada `cast_size`.
# 3. Obtén el resumen estadístico (`describe()`) de `cast_size`.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Pregunta de reflexión 2:** Compara `mean` con `50%` (mediana) de `cast_size`. ¿Son parecidos o muy distintos? ¿Qué te sugiere eso sobre la forma de la distribución (simétrica vs. sesgada)?

# %% [markdown]
# ### Ejercicio 2.2 — Histograma
# Genera un histograma de `cast_size` con 30 intervalos (`bins`).

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Pregunta de reflexión 3:** ¿La forma del histograma se parece a una "campana" (distribución normal), como en el taller de `StudentsPerformance.csv`? ¿O tiene una cola larga hacia algún lado? ¿Cómo se relaciona esa forma con lo que respondiste en la pregunta de reflexión 2?

# %% [markdown]
# ### Ejercicio 2.3 — Comparar actores vs. directores
# Repite el mismo procedimiento del ejercicio 2.1 pero filtrando `role == "DIRECTOR"`, para obtener una variable `director_size` (número de directores acreditados por película). Compara el `describe()` de `cast_size` con el de `director_size`.

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Pregunta de reflexión 4:** ¿Cuál de las dos variables tiene mayor dispersión (`std`)? ¿A qué crees que se debe esa diferencia?

# %% [markdown]
# ---
# ## Parte 3 — Reto integrador (opcional)
#
# Usa la variable `cast_size` que construiste en la Parte 2 para encontrar **las 10 películas con el reparto más grande** (ordena de mayor a menor y muestra las primeras 10).

# %%
# TU CÓDIGO AQUÍ

# %% [markdown]
# **Pregunta de cierre:** ¿Qué hipótesis plantearías para explicar por qué algunas películas tienen un reparto tan grande? ¿El dataset te permite confirmar esa hipótesis, o solo te permite describir el patrón?
